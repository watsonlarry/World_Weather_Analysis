# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

from datetime import datetime
from scipy.stats import linregress
from citipy import citipy
from config import weather_api_key

# Base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
cities
# Out:
# ['new norfolk',
#  'dikson',
#  'palmer',
#  'taolanaro',
#  'rikitea',
#  'arraial do cabo',
#  'hobart',
#  'bredasdorp',
#  'alekseyevka',
#  'saldanha',
#  'tuktoyaktuk',
#  'roma',
#  'port elizabeth',
#  'mataura',
#  'omboue',
#  'yellowknife',
#  'periyanayakkanpalaiyam',
#  'cape town',
#  'bluff',
#  'richards bay',
#  'ushuaia',
#  'bhanpura',
#  'srednekolymsk',
#  'luderitz',
#  'adrar',
#  'ust-kuyga',
#  'ekibastuz',
#  'derzhavinsk',
#  'severo-yeniseyskiy',
#  'zaoyang',
#  'irbeyskoye',
#  'busselton',
#  'padang',
#  'port alfred',
#  'belushya guba',
#  'lebu',
#  'faanui',
#  'vilcun',
#  'mys shmidta',
#  'pangai',
#  'butaritari',
#  'atuona',
#  'henties bay',
#  'arlit',
#  'hasaki',
#  'trinidad',
#  'saskylakh',
#  'talnakh',
#  'bam',
#  'nizhneyansk',
#  'balabac',
#  'salalah',
#  'nikolskoye',
#  'tabas',
#  'pevek',
#  'husavik',
#  'maragogi',
#  'jamestown',
#  'san policarpo',
#  'narsaq',
#  'punta arenas',
#  'carutapera',
#  'ixtapa',
#  'pembroke',
#  'saint-philippe',
#  'mar del plata',
#  'calais',
#  'beringovskiy',
#  'garowe',
#  'guerrero negro',
#  'fukue',
#  'provideniya',
#  'ogaminana',
#  'kapaa',
#  'ossora',
#  'thaba-tseka',
#  'urut',
#  'esperance',
#  'kahului',
#  'khatanga',
#  'hambantota',
#  'kaeo',
#  'ostrovnoy',
#  'neryungri',
#  'barrow',
#  'hithadhoo',
#  'biltine',
#  'ponta do sol',
#  'nyagan',
#  'basco',
#  'the valley',
#  'castro',
#  'rajapur',
#  'conchas',
#  'monroe',
#  'solnechnyy',
#  'clyde river',
#  'hermanus',
#  'pingliang',
#  'taoudenni',
#  'zaysan',
#  'vaini',
#  'esso',
#  'vestmanna',
#  'borogontsy',
#  'peleduy',
#  'bathsheba',
#  'amudat',
#  'barbar',
#  'east london',
#  'orichi',
#  'norman wells',
#  'sao sebastiao',
#  'albany',
#  'bethel',
#  'leningradskiy',
#  'tiksi',
#  'chimbote',
#  'hami',
#  'vostok',
#  'puerto ayora',
#  'miri',
#  'grand river south east',
#  'ancud',
#  'awbari',
#  'kruisfontein',
#  'matara',
#  'umzimvubu',
#  'onega',
#  'puksoozero',
#  'avarua',
#  'coihaique',
#  'touros',
#  'ribeira grande',
#  'gari',
#  'vestmannaeyjar',
#  'kaitangata',
#  'rudolstadt',
#  'pacific grove',
#  'maloy',
#  'moose factory',
#  'delhi',
#  'saint-augustin',
#  'kargil',
#  'illoqqortoormiut',
#  'flinders',
#  'tasiilaq',
#  'port hawkesbury',
#  'cidreira',
#  'mehamn',
#  'makakilo city',
#  'severo-kurilsk',
#  'longyearbyen',
#  'tsihombe',
#  'meulaboh',
#  'great yarmouth',
#  'goryachiy klyuch',
#  'vanavara',
#  'saint-georges',
#  'gat',
#  'urcos',
#  'paamiut',
#  'caconde',
#  'torbay',
#  'las vegas',
#  'bolungarvik',
#  'ahipara',
#  'amderma',
#  'chuy',
#  'balod',
#  'constitucion',
#  'birao',
#  'mayo',
#  'la ronge',
#  'harper',
#  'asau',
#  'san quintin',
#  'dubbo',
#  'atbasar',
#  'thompson',
#  'bambous virieux',
#  'waddan',
#  'barentsburg',
#  'bandarbeyla',
#  'port-cartier',
#  'tiarei',
#  'aswan',
#  'balaka',
#  'umred',
#  'tidore',
#  'carnarvon',
#  'binabalian',
#  'spirit river',
#  'kisangani',
#  'cockburn town',
#  'chokurdakh',
#  'sri aman',
#  'bengkulu',
#  'tasbuget',
#  'hilo',
#  'eyl',
#  'midland',
#  'praia da vitoria',
#  'saleaula',
#  'gemena',
#  'illapel',
#  'diffa',
#  'labuhan',
#  'port lincoln',
#  'petropavlovsk-kamchatskiy',
#  'atambua',
#  'vila franca do campo',
#  'westport',
#  'shaoguan',
#  'gaya',
#  'sao filipe',
#  'angoram',
#  'samarai',
#  'porlamar',
#  'artyk',
#  'kenitra',
#  'geraldton',
#  'dingle',
#  'mantenopolis',
#  'pachino',
#  'bilibino',
#  'chapais',
#  'sao felix do xingu',
#  'shingu',
#  'indapur',
#  'mahibadhoo',
#  'the pas',
#  'weatherford',
#  'albion',
#  'sinnamary',
#  'airai',
#  'ondorhaan',
#  'georgetown',
#  'solwezi',
#  'souillac',
#  'montepuez',
#  'erenhot',
#  'faya',
#  'royan',
#  'daru',
#  'stokmarknes',
#  'manyana',
#  'bhit shah',
#  'rawson',
#  'vila velha',
#  'alberton',
#  'pisco',
#  'odweyne',
#  'grindavik',
#  'nabire',
#  'san patricio',
#  'nantucket',
#  'sinkat',
#  'muli',
#  'dawson creek',
#  'lagoa',
#  'marawi',
#  'karratha',
#  'oktyabrskoye',
#  'lavrentiya',
#  'bafoulabe',
#  'pangody',
#  'lompoc',
#  'tuatapere',
#  'annau',
#  'sakakah',
#  'necochea',
#  'sentyabrskiy',
#  'rincon',
#  'qaanaaq',
#  'broome',
#  'sola',
#  'yara',
#  'nizhniy kuranakh',
#  'puerto guzman',
#  'cayenne',
#  'boundiali',
#  'bonham',
#  'ascension',
#  'mantua',
#  'hobyo',
#  'general roca',
#  'magadan',
#  'coquimbo',
#  'gazojak',
#  'tilichiki',
#  'mount gambier',
#  'taraz',
#  'severnyy',
#  'half moon bay',
#  'abu samrah',
#  'kavieng',
#  'oranjemund',
#  'eirunepe',
#  'barentu',
#  'umm kaddadah',
#  'mahebourg',
#  'camacha',
#  'gwadar',
#  'bom jesus da lapa',
#  'chiredzi',
#  'carauari',
#  'marzuq',
#  'batagay-alyta',
#  'khandyga',
#  'quesnel',
#  'klaksvik',
#  'vilyuysk',
#  'sivaki',
#  'karauzyak',
#  'conakry',
#  'caravelas',
#  'tumannyy',
#  'heiligenhafen',
#  'tateyama',
#  'jumla',
#  'puunsi',
#  'simian',
#  'tutayev',
#  'nemuro',
#  'verkhnevilyuysk',
#  'mahon',
#  'yanan',
#  'plettenberg bay',
#  'kalmunai',
#  'acari',
#  'isangel',
#  'cangzhou',
#  'mrirt',
#  'aras',
#  'fortuna',
#  'berlevag',
#  'vanimo',
#  'baherden',
#  'alotau',
#  'viesite',
#  'andros town',
#  'dunedin',
#  'honiara',
#  'galle',
#  'grants',
#  'huilong',
#  'kirs',
#  'umm lajj',
#  'qujing',
#  'margate',
#  'narsipatnam',
#  'kortkeros',
#  'sal rei',
#  'manggar',
#  'cabo san lucas',
#  'kasulu',
#  'imbituba',
#  'japura',
#  'noveleta',
#  'broken hill',
#  'tezpur',
#  'yatou',
#  'takaka',
#  'manaquiri',
#  'lata',
#  'vardo',
#  'nizwa',
#  'ilulissat',
#  'hovd',
#  'pecanha',
#  'porto novo',
#  'jacareacanga',
#  'razole',
#  'taywarah',
#  'aasiaat',
#  'nyrob',
#  'attawapiskat',
#  'metehara',
#  'alyangula',
#  'savinka',
#  'vagur',
#  'semey',
#  'bjornevatn',
#  'iqaluit',
#  'xining',
#  'nuuk',
#  'suntar',
#  'kodiak',
#  'batemans bay',
#  'springbok',
#  'kez',
#  'turukhansk',
#  'victoria',
#  'billings',
#  'tromso',
#  'jasper',
#  'olinda',
#  'thinadhoo',
#  'taltal',
#  'cap malheureux',
#  'batagay',
#  'qasigiannguit',
#  'aklavik',
#  'sistranda',
#  'road town',
#  'lufilufi',
#  'cedral',
#  'puerto baquerizo moreno',
#  'los alamos',
#  'batesville',
#  'am timan',
#  'bowen',
#  'great falls',
#  'koutsouras',
#  'chokwe',
#  'solginskiy',
#  'mogochin',
#  'chipata',
#  'napasar',
#  'vaitupu',
#  'ayolas',
#  'dakar',
#  'morros',
#  'trondheim',
#  'bara',
#  'pokhara',
#  'healesville',
#  'yulara',
#  'simpang',
#  'tungkang',
#  'kamenskoye',
#  'luanda',
#  'anito',
#  'hrubieszow',
#  'codrington',
#  'tautira',
#  'saint george',
#  'banon',
#  'naze',
#  'providencia',
#  'katsuura',
#  'mana',
#  'stuttgart',
#  'namatanai',
#  'tukrah',
#  'kawalu',
#  'chagda',
#  'port hardy',
#  'iracoubo',
#  'lasa',
#  'ayacucho',
#  'sedelnikovo',
#  'wahiawa',
#  'ler',
#  'nome',
#  'samusu',
#  'giyani',
#  'labutta',
#  'sao joao da barra',
#  'pryazha',
#  'pringsewu',
#  'gizo',
#  'te anau',
#  'george town',
#  'chumikan',
#  'buala',
#  'west lorne',
#  'key largo',
#  'muroran',
#  'waynesboro',
#  'sabalgarh',
#  'nenjiang',
#  'pumiao',
#  'mpika',
#  'osa',
#  'kostino',
#  'kurayoshi',
#  'denizli',
#  'huarmey',
#  'mocuba',
#  'berbera',
#  'fayaoue',
#  'rapid valley',
#  'gidam',
#  'prince rupert',
#  'aflu',
#  'kununurra',
#  'mackenzie',
#  'mbamba',
#  'fonte boa',
#  'cabedelo',
#  'toliary',
#  'urengoy',
#  'manali',
#  'taman',
#  'caconda',
#  'price',
#  'coahuayana',
#  'texarkana',
#  'tomatlan',
#  'hofn',
#  'seymchan',
#  'fujin',
#  'saint-francois',
#  'northam',
#  'bali',
#  'dobryanka',
#  'hammerfest',
#  'alvorada',
#  'orleans',
#  'bolobo',
#  'kasama',
#  'port keats',
#  'rudnya',
#  'ji-parana',
#  'la ciotat',
#  'oswego',
#  'yining',
#  'sitka',
#  'kungurtug',
#  'mangrol',
#  'shelburne',
#  'northglenn',
#  'agaro',
#  'gornozavodsk',
#  'washington',
#  'marcona',
#  'sattahip',
#  'misratah',
#  'dondo',
#  'natal',
#  'ambon',
#  'soavinandriana',
#  'tawnat',
#  'skibbereen',
#  'buluang',
#  'sungairaya',
#  'mazagao',
#  'los llanos de aridane',
#  'sioux lookout',
#  'fort william',
#  'baykit',
#  'palabuhanratu',
#  'belmonte',
#  'denpasar',
#  'udachnyy',
#  'namibe',
#  'ulundi',
#  'la concepcion',
#  'sao gabriel da cachoeira',
#  'sovetskiy',
#  'igarka',
#  'martapura',
#  'birnin kebbi',
#  'zhanakorgan',
#  'evensk',
#  'villa del rosario',
#  'mecca',
#  'londonderry',
#  'tucumcari',
#  'tres arroyos',
#  'yabrud',
#  'penzance',
#  'kibara',
#  'ahvaz',
#  'lakatoro',
#  'luena',
#  'bur gabo',
#  'luganville',
#  'kenai',
#  'presidencia roque saenz pena',
#  'colares',
#  'port macquarie',
#  'cururupu',
#  'gisborne',
#  'tymovskoye',
#  'college',
#  'moerai',
#  'tashtyp',
#  'moundou',
#  'beloha',
#  'carinhanha',
#  'nelson bay',
#  'anadyr',
#  'thiruvananthapuram',
#  'benito juarez',
#  'corinto',
#  'la cruz',
#  'jizan',
#  'bambanglipuro',
#  'champerico',
#  'sainte-anne-des-monts',
#  'goiania',
#  'kaplice',
#  'picsi',
#  'lorengau',
#  'haines junction',
#  'manbij',
#  'zheleznodorozhnyy',
#  'cherskiy',
#  'sao joao batista',
#  'gillette',
#  'saint anthony',
#  'izvestkovyy',
#  'upernavik',
#  'puro',
#  'potchefstroom',
#  'mulki',
#  'alofi',
#  'brae',
#  'portland',
#  'jalu',
#  'salamiyah',
#  'altay',
#  'ranong',
#  'san cristobal',
#  'aitape',
#  'taksimo',
#  'belaya gora',
#  'wageningen',
#  'doctor pedro p. pena',
#  'katobu',
#  'najran',
#  'saryozek',
#  'houma',
#  'dalianwan',
#  'mbandaka',
#  'felipe carrillo puerto',
#  'banes',
#  'conceicao da barra',
#  'tadine',
#  'kyren',
#  'blagoyevo',
#  'hirara',
#  'tyrma',
#  'ligayan',
#  'alta floresta',
#  'san borja',
#  'vuktyl',
#  'sambava',
#  'rabo de peixe',
#  'mnogovershinnyy',
#  'lamont',
#  'barroualie',
#  'muros',
#  'manavalakurichi',
#  'tambacounda',
#  'konstantinovskoye',
#  'vada',
#  'dunda',
#  'puerto escondido',
#  'ishigaki',
#  'pangnirtung',
#  'auki',
#  'alice springs',
#  'rongcheng',
#  'swakopmund',
#  'teguldet',
#  'hualmay',
#  'manokwari',
#  'angra',
#  'kavaratti',
#  'kyra',
#  'grand-santi',
#  'yagodnoye',
#  'ust-omchug',
#  'ballina',
#  'louisbourg',
#  'tsabong',
#  'nanortalik',
#  'costinesti',
#  'fasa',
#  'rio grande',
#  'moyale',
#  'balas',
#  'talaya',
#  'baft',
#  'oga',
#  'cagayan de tawi-tawi',
#  'nyurba',
#  'mount isa',
#  'healdsburg',
#  'zatoka',
#  'monrovia',
#  'berdigestyakh',
#  'alexandria',
#  'zabol',
#  'marshfield',
#  'kangaatsiaq',
#  'daxian',
#  'cascais',
#  'mandalgovi',
#  'upata',
#  'kathu',
#  'grande-riviere',
#  'sesheke',
#  'casablanca',
#  'elko',
#  'ahome',
#  'ojinaga',
#  'comodoro rivadavia',
#  'warqla',
#  'lima',
#  'sao raimundo das mangabeiras',
#  'uaua',
#  'nanakuli',
#  'monster',
#  'yangambi',
#  'armidale',
#  'okha',
#  'simplicio mendes',
#  'nalut',
#  'scottsburgh',
#  'darfield',
#  'bud',
#  'hamilton',
#  'rawannawi',
#  'tynda',
#  'port blair',
#  'matamoros',
#  'ocotal',
#  'kashi',
#  'high level',
#  'itaituba',
#  'ust-maya',
#  'avera']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": city_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | palmer
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | alekseyevka
# Processing Record 10 of Set 1 | saldanha
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | roma
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | omboue
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | periyanayakkanpalaiyam
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | richards bay
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | bhanpura
# Processing Record 23 of Set 1 | srednekolymsk
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | adrar
# Processing Record 26 of Set 1 | ust-kuyga
# Processing Record 27 of Set 1 | ekibastuz
# Processing Record 28 of Set 1 | derzhavinsk
# Processing Record 29 of Set 1 | severo-yeniseyskiy
# Processing Record 30 of Set 1 | zaoyang
# Processing Record 31 of Set 1 | irbeyskoye
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | padang
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | vilcun
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | pangai
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | henties bay
# Processing Record 44 of Set 1 | arlit
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | trinidad
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | bam
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | balabac
# Processing Record 2 of Set 2 | salalah
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | tabas
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | husavik
# Processing Record 7 of Set 2 | maragogi
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | san policarpo
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | carutapera
# Processing Record 13 of Set 2 | ixtapa
# Processing Record 14 of Set 2 | pembroke
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | calais
# Processing Record 18 of Set 2 | beringovskiy
# Processing Record 19 of Set 2 | garowe
# Processing Record 20 of Set 2 | guerrero negro
# Processing Record 21 of Set 2 | fukue
# Processing Record 22 of Set 2 | provideniya
# Processing Record 23 of Set 2 | ogaminana
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | ossora
# Processing Record 26 of Set 2 | thaba-tseka
# Processing Record 27 of Set 2 | urut
# Processing Record 28 of Set 2 | esperance
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | hambantota
# Processing Record 32 of Set 2 | kaeo
# Processing Record 33 of Set 2 | ostrovnoy
# Processing Record 34 of Set 2 | neryungri
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | biltine
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | nyagan
# Processing Record 40 of Set 2 | basco
# Processing Record 41 of Set 2 | the valley
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | rajapur
# Processing Record 44 of Set 2 | conchas
# Processing Record 45 of Set 2 | monroe
# Processing Record 46 of Set 2 | solnechnyy
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | pingliang
# Processing Record 50 of Set 2 | taoudenni
# Processing Record 1 of Set 3 | zaysan
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | esso
# Processing Record 4 of Set 3 | vestmanna
# Processing Record 5 of Set 3 | borogontsy
# Processing Record 6 of Set 3 | peleduy
# Processing Record 7 of Set 3 | bathsheba
# Processing Record 8 of Set 3 | amudat
# Processing Record 9 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | orichi
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | sao sebastiao
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | leningradskiy
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | chimbote
# Processing Record 19 of Set 3 | hami
# Processing Record 20 of Set 3 | vostok
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | miri
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | awbari
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | matara
# Processing Record 28 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 3 | onega
# Processing Record 30 of Set 3 | puksoozero
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | coihaique
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | gari
# Processing Record 36 of Set 3 | vestmannaeyjar
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | rudolstadt
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | maloy
# Processing Record 41 of Set 3 | moose factory
# Processing Record 42 of Set 3 | delhi
# Processing Record 43 of Set 3 | saint-augustin
# Processing Record 44 of Set 3 | kargil
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | flinders
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | port hawkesbury
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | mehamn
# Processing Record 1 of Set 4 | makakilo city
# Processing Record 2 of Set 4 | severo-kurilsk
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | meulaboh
# Processing Record 6 of Set 4 | great yarmouth
# Processing Record 7 of Set 4 | goryachiy klyuch
# Processing Record 8 of Set 4 | vanavara
# Processing Record 9 of Set 4 | saint-georges
# Processing Record 10 of Set 4 | gat
# Processing Record 11 of Set 4 | urcos
# Processing Record 12 of Set 4 | paamiut
# Processing Record 13 of Set 4 | caconde
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | las vegas
# Processing Record 16 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 4 | ahipara
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | balod
# Processing Record 21 of Set 4 | constitucion
# Processing Record 22 of Set 4 | birao
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | la ronge
# Processing Record 25 of Set 4 | harper
# Processing Record 26 of Set 4 | asau
# Processing Record 27 of Set 4 | san quintin
# Processing Record 28 of Set 4 | dubbo
# Processing Record 29 of Set 4 | atbasar
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | waddan
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | bandarbeyla
# Processing Record 35 of Set 4 | port-cartier
# Processing Record 36 of Set 4 | tiarei
# Processing Record 37 of Set 4 | aswan
# Processing Record 38 of Set 4 | balaka
# Processing Record 39 of Set 4 | umred
# Processing Record 40 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | binabalian
# Processing Record 43 of Set 4 | spirit river
# Processing Record 44 of Set 4 | kisangani
# Processing Record 45 of Set 4 | cockburn town
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | sri aman
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 4 | hilo
# Processing Record 1 of Set 5 | eyl
# Processing Record 2 of Set 5 | midland
# Processing Record 3 of Set 5 | praia da vitoria
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 5 | gemena
# Processing Record 6 of Set 5 | illapel
# Processing Record 7 of Set 5 | diffa
# Processing Record 8 of Set 5 | labuhan
# Processing Record 9 of Set 5 | port lincoln
# Processing Record 10 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 5 | atambua
# Processing Record 12 of Set 5 | vila franca do campo
# Processing Record 13 of Set 5 | westport
# Processing Record 14 of Set 5 | shaoguan
# Processing Record 15 of Set 5 | gaya
# Processing Record 16 of Set 5 | sao filipe
# Processing Record 17 of Set 5 | angoram
# Processing Record 18 of Set 5 | samarai
# Processing Record 19 of Set 5 | porlamar
# Processing Record 20 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 5 | kenitra
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | mantenopolis
# Processing Record 25 of Set 5 | pachino
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | chapais
# Processing Record 28 of Set 5 | sao felix do xingu
# Processing Record 29 of Set 5 | shingu
# Processing Record 30 of Set 5 | indapur
# Processing Record 31 of Set 5 | mahibadhoo
# Processing Record 32 of Set 5 | the pas
# Processing Record 33 of Set 5 | weatherford
# Processing Record 34 of Set 5 | albion
# Processing Record 35 of Set 5 | sinnamary
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | solwezi
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | montepuez
# Processing Record 42 of Set 5 | erenhot
# Processing Record 43 of Set 5 | faya
# Processing Record 44 of Set 5 | royan
# Processing Record 45 of Set 5 | daru
# Processing Record 46 of Set 5 | stokmarknes
# Processing Record 47 of Set 5 | manyana
# Processing Record 48 of Set 5 | bhit shah
# Processing Record 49 of Set 5 | rawson
# Processing Record 50 of Set 5 | vila velha
# Processing Record 1 of Set 6 | alberton
# Processing Record 2 of Set 6 | pisco
# Processing Record 3 of Set 6 | odweyne
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | nabire
# Processing Record 6 of Set 6 | san patricio
# Processing Record 7 of Set 6 | nantucket
# Processing Record 8 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 6 | muli
# Processing Record 10 of Set 6 | dawson creek
# Processing Record 11 of Set 6 | lagoa
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | karratha
# Processing Record 14 of Set 6 | oktyabrskoye
# Processing Record 15 of Set 6 | lavrentiya
# Processing Record 16 of Set 6 | bafoulabe
# Processing Record 17 of Set 6 | pangody
# Processing Record 18 of Set 6 | lompoc
# Processing Record 19 of Set 6 | tuatapere
# Processing Record 20 of Set 6 | annau
# Processing Record 21 of Set 6 | sakakah
# Processing Record 22 of Set 6 | necochea
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | rincon
# Processing Record 25 of Set 6 | qaanaaq
# Processing Record 26 of Set 6 | broome
# Processing Record 27 of Set 6 | sola
# Processing Record 28 of Set 6 | yara
# Processing Record 29 of Set 6 | nizhniy kuranakh
# Processing Record 30 of Set 6 | puerto guzman
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | boundiali
# Processing Record 33 of Set 6 | bonham
# Processing Record 34 of Set 6 | ascension
# Processing Record 35 of Set 6 | mantua
# Processing Record 36 of Set 6 | hobyo
# Processing Record 37 of Set 6 | general roca
# Processing Record 38 of Set 6 | magadan
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | gazojak
# Processing Record 41 of Set 6 | tilichiki
# Processing Record 42 of Set 6 | mount gambier
# Processing Record 43 of Set 6 | taraz
# Processing Record 44 of Set 6 | severnyy
# Processing Record 45 of Set 6 | half moon bay
# Processing Record 46 of Set 6 | abu samrah
# Processing Record 47 of Set 6 | kavieng
# Processing Record 48 of Set 6 | oranjemund
# Processing Record 49 of Set 6 | eirunepe
# Processing Record 50 of Set 6 | barentu
# Processing Record 1 of Set 7 | umm kaddadah
# Processing Record 2 of Set 7 | mahebourg
# Processing Record 3 of Set 7 | camacha
# Processing Record 4 of Set 7 | gwadar
# Processing Record 5 of Set 7 | bom jesus da lapa
# Processing Record 6 of Set 7 | chiredzi
# Processing Record 7 of Set 7 | carauari
# Processing Record 8 of Set 7 | marzuq
# Processing Record 9 of Set 7 | batagay-alyta
# Processing Record 10 of Set 7 | khandyga
# Processing Record 11 of Set 7 | quesnel
# Processing Record 12 of Set 7 | klaksvik
# Processing Record 13 of Set 7 | vilyuysk
# Processing Record 14 of Set 7 | sivaki
# Processing Record 15 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 7 | conakry
# Processing Record 17 of Set 7 | caravelas
# Processing Record 18 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 7 | heiligenhafen
# Processing Record 20 of Set 7 | tateyama
# Processing Record 21 of Set 7 | jumla
# Processing Record 22 of Set 7 | puunsi
# City not found. Skipping...
# Processing Record 23 of Set 7 | simian
# Processing Record 24 of Set 7 | tutayev
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | verkhnevilyuysk
# Processing Record 27 of Set 7 | mahon
# Processing Record 28 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 29 of Set 7 | plettenberg bay
# Processing Record 30 of Set 7 | kalmunai
# Processing Record 31 of Set 7 | acari
# Processing Record 32 of Set 7 | isangel
# Processing Record 33 of Set 7 | cangzhou
# Processing Record 34 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 7 | aras
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | berlevag
# Processing Record 38 of Set 7 | vanimo
# Processing Record 39 of Set 7 | baherden
# Processing Record 40 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 7 | viesite
# Processing Record 42 of Set 7 | andros town
# Processing Record 43 of Set 7 | dunedin
# Processing Record 44 of Set 7 | honiara
# Processing Record 45 of Set 7 | galle
# Processing Record 46 of Set 7 | grants
# Processing Record 47 of Set 7 | huilong
# Processing Record 48 of Set 7 | kirs
# Processing Record 49 of Set 7 | umm lajj
# Processing Record 50 of Set 7 | qujing
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | narsipatnam
# Processing Record 3 of Set 8 | kortkeros
# Processing Record 4 of Set 8 | sal rei
# Processing Record 5 of Set 8 | manggar
# Processing Record 6 of Set 8 | cabo san lucas
# Processing Record 7 of Set 8 | kasulu
# Processing Record 8 of Set 8 | imbituba
# Processing Record 9 of Set 8 | japura
# Processing Record 10 of Set 8 | noveleta
# Processing Record 11 of Set 8 | broken hill
# Processing Record 12 of Set 8 | tezpur
# Processing Record 13 of Set 8 | yatou
# Processing Record 14 of Set 8 | takaka
# Processing Record 15 of Set 8 | manaquiri
# Processing Record 16 of Set 8 | lata
# Processing Record 17 of Set 8 | vardo
# Processing Record 18 of Set 8 | nizwa
# Processing Record 19 of Set 8 | ilulissat
# Processing Record 20 of Set 8 | hovd
# Processing Record 21 of Set 8 | pecanha
# Processing Record 22 of Set 8 | porto novo
# Processing Record 23 of Set 8 | jacareacanga
# Processing Record 24 of Set 8 | razole
# Processing Record 25 of Set 8 | taywarah
# Processing Record 26 of Set 8 | aasiaat
# Processing Record 27 of Set 8 | nyrob
# Processing Record 28 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 8 | metehara
# City not found. Skipping...
# Processing Record 30 of Set 8 | alyangula
# Processing Record 31 of Set 8 | savinka
# Processing Record 32 of Set 8 | vagur
# Processing Record 33 of Set 8 | semey
# Processing Record 34 of Set 8 | bjornevatn
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | xining
# Processing Record 37 of Set 8 | nuuk
# Processing Record 38 of Set 8 | suntar
# Processing Record 39 of Set 8 | kodiak
# Processing Record 40 of Set 8 | batemans bay
# Processing Record 41 of Set 8 | springbok
# Processing Record 42 of Set 8 | kez
# Processing Record 43 of Set 8 | turukhansk
# Processing Record 44 of Set 8 | victoria
# Processing Record 45 of Set 8 | billings
# Processing Record 46 of Set 8 | tromso
# Processing Record 47 of Set 8 | jasper
# Processing Record 48 of Set 8 | olinda
# Processing Record 49 of Set 8 | thinadhoo
# Processing Record 50 of Set 8 | taltal
# Processing Record 1 of Set 9 | cap malheureux
# Processing Record 2 of Set 9 | batagay
# Processing Record 3 of Set 9 | qasigiannguit
# Processing Record 4 of Set 9 | aklavik
# Processing Record 5 of Set 9 | sistranda
# Processing Record 6 of Set 9 | road town
# Processing Record 7 of Set 9 | lufilufi
# Processing Record 8 of Set 9 | cedral
# Processing Record 9 of Set 9 | puerto baquerizo moreno
# Processing Record 10 of Set 9 | los alamos
# Processing Record 11 of Set 9 | batesville
# Processing Record 12 of Set 9 | am timan
# Processing Record 13 of Set 9 | bowen
# Processing Record 14 of Set 9 | great falls
# Processing Record 15 of Set 9 | koutsouras
# Processing Record 16 of Set 9 | chokwe
# Processing Record 17 of Set 9 | solginskiy
# Processing Record 18 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 19 of Set 9 | chipata
# Processing Record 20 of Set 9 | napasar
# Processing Record 21 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 9 | ayolas
# Processing Record 23 of Set 9 | dakar
# Processing Record 24 of Set 9 | morros
# Processing Record 25 of Set 9 | trondheim
# Processing Record 26 of Set 9 | bara
# Processing Record 27 of Set 9 | pokhara
# Processing Record 28 of Set 9 | healesville
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | simpang
# Processing Record 31 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 32 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 9 | luanda
# Processing Record 34 of Set 9 | anito
# Processing Record 35 of Set 9 | hrubieszow
# Processing Record 36 of Set 9 | codrington
# Processing Record 37 of Set 9 | tautira
# Processing Record 38 of Set 9 | saint george
# Processing Record 39 of Set 9 | banon
# Processing Record 40 of Set 9 | naze
# Processing Record 41 of Set 9 | providencia
# Processing Record 42 of Set 9 | katsuura
# Processing Record 43 of Set 9 | mana
# Processing Record 44 of Set 9 | stuttgart
# Processing Record 45 of Set 9 | namatanai
# Processing Record 46 of Set 9 | tukrah
# Processing Record 47 of Set 9 | kawalu
# Processing Record 48 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 9 | port hardy
# Processing Record 50 of Set 9 | iracoubo
# Processing Record 1 of Set 10 | lasa
# Processing Record 2 of Set 10 | ayacucho
# Processing Record 3 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 10 | wahiawa
# Processing Record 5 of Set 10 | ler
# Processing Record 6 of Set 10 | nome
# Processing Record 7 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 10 | giyani
# Processing Record 9 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 10 | sao joao da barra
# Processing Record 11 of Set 10 | pryazha
# Processing Record 12 of Set 10 | pringsewu
# Processing Record 13 of Set 10 | gizo
# Processing Record 14 of Set 10 | te anau
# Processing Record 15 of Set 10 | george town
# Processing Record 16 of Set 10 | chumikan
# Processing Record 17 of Set 10 | buala
# Processing Record 18 of Set 10 | west lorne
# Processing Record 19 of Set 10 | key largo
# Processing Record 20 of Set 10 | muroran
# Processing Record 21 of Set 10 | waynesboro
# Processing Record 22 of Set 10 | sabalgarh
# Processing Record 23 of Set 10 | nenjiang
# Processing Record 24 of Set 10 | pumiao
# Processing Record 25 of Set 10 | mpika
# Processing Record 26 of Set 10 | osa
# Processing Record 27 of Set 10 | kostino
# Processing Record 28 of Set 10 | kurayoshi
# Processing Record 29 of Set 10 | denizli
# Processing Record 30 of Set 10 | huarmey
# Processing Record 31 of Set 10 | mocuba
# Processing Record 32 of Set 10 | berbera
# Processing Record 33 of Set 10 | fayaoue
# Processing Record 34 of Set 10 | rapid valley
# Processing Record 35 of Set 10 | gidam
# Processing Record 36 of Set 10 | prince rupert
# Processing Record 37 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 10 | kununurra
# Processing Record 39 of Set 10 | mackenzie
# Processing Record 40 of Set 10 | mbamba
# Processing Record 41 of Set 10 | fonte boa
# Processing Record 42 of Set 10 | cabedelo
# Processing Record 43 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 10 | urengoy
# Processing Record 45 of Set 10 | manali
# Processing Record 46 of Set 10 | taman
# Processing Record 47 of Set 10 | caconda
# Processing Record 48 of Set 10 | price
# Processing Record 49 of Set 10 | coahuayana
# Processing Record 50 of Set 10 | texarkana
# Processing Record 1 of Set 11 | tomatlan
# Processing Record 2 of Set 11 | hofn
# Processing Record 3 of Set 11 | seymchan
# Processing Record 4 of Set 11 | fujin
# Processing Record 5 of Set 11 | saint-francois
# Processing Record 6 of Set 11 | northam
# Processing Record 7 of Set 11 | bali
# Processing Record 8 of Set 11 | dobryanka
# Processing Record 9 of Set 11 | hammerfest
# Processing Record 10 of Set 11 | alvorada
# Processing Record 11 of Set 11 | orleans
# Processing Record 12 of Set 11 | bolobo
# Processing Record 13 of Set 11 | kasama
# Processing Record 14 of Set 11 | port keats
# Processing Record 15 of Set 11 | rudnya
# Processing Record 16 of Set 11 | ji-parana
# City not found. Skipping...
# Processing Record 17 of Set 11 | la ciotat
# Processing Record 18 of Set 11 | oswego
# Processing Record 19 of Set 11 | yining
# Processing Record 20 of Set 11 | sitka
# Processing Record 21 of Set 11 | kungurtug
# Processing Record 22 of Set 11 | mangrol
# Processing Record 23 of Set 11 | shelburne
# Processing Record 24 of Set 11 | northglenn
# Processing Record 25 of Set 11 | agaro
# Processing Record 26 of Set 11 | gornozavodsk
# Processing Record 27 of Set 11 | washington
# Processing Record 28 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 11 | sattahip
# Processing Record 30 of Set 11 | misratah
# Processing Record 31 of Set 11 | dondo
# Processing Record 32 of Set 11 | natal
# Processing Record 33 of Set 11 | ambon
# Processing Record 34 of Set 11 | soavinandriana
# Processing Record 35 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 36 of Set 11 | skibbereen
# Processing Record 37 of Set 11 | buluang
# Processing Record 38 of Set 11 | sungairaya
# Processing Record 39 of Set 11 | mazagao
# Processing Record 40 of Set 11 | los llanos de aridane
# Processing Record 41 of Set 11 | sioux lookout
# Processing Record 42 of Set 11 | fort william
# Processing Record 43 of Set 11 | baykit
# Processing Record 44 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 11 | belmonte
# Processing Record 46 of Set 11 | denpasar
# Processing Record 47 of Set 11 | udachnyy
# Processing Record 48 of Set 11 | namibe
# Processing Record 49 of Set 11 | ulundi
# Processing Record 50 of Set 11 | la concepcion
# Processing Record 1 of Set 12 | sao gabriel da cachoeira
# Processing Record 2 of Set 12 | sovetskiy
# Processing Record 3 of Set 12 | igarka
# Processing Record 4 of Set 12 | martapura
# Processing Record 5 of Set 12 | birnin kebbi
# Processing Record 6 of Set 12 | zhanakorgan
# Processing Record 7 of Set 12 | evensk
# Processing Record 8 of Set 12 | villa del rosario
# Processing Record 9 of Set 12 | mecca
# Processing Record 10 of Set 12 | londonderry
# Processing Record 11 of Set 12 | tucumcari
# Processing Record 12 of Set 12 | tres arroyos
# Processing Record 13 of Set 12 | yabrud
# Processing Record 14 of Set 12 | penzance
# Processing Record 15 of Set 12 | kibara
# Processing Record 16 of Set 12 | ahvaz
# Processing Record 17 of Set 12 | lakatoro
# Processing Record 18 of Set 12 | luena
# Processing Record 19 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 12 | luganville
# Processing Record 21 of Set 12 | kenai
# Processing Record 22 of Set 12 | presidencia roque saenz pena
# Processing Record 23 of Set 12 | colares
# Processing Record 24 of Set 12 | port macquarie
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | gisborne
# Processing Record 27 of Set 12 | tymovskoye
# Processing Record 28 of Set 12 | college
# Processing Record 29 of Set 12 | moerai
# Processing Record 30 of Set 12 | tashtyp
# Processing Record 31 of Set 12 | moundou
# Processing Record 32 of Set 12 | beloha
# Processing Record 33 of Set 12 | carinhanha
# Processing Record 34 of Set 12 | nelson bay
# Processing Record 35 of Set 12 | anadyr
# Processing Record 36 of Set 12 | thiruvananthapuram
# Processing Record 37 of Set 12 | benito juarez
# Processing Record 38 of Set 12 | corinto
# Processing Record 39 of Set 12 | la cruz
# Processing Record 40 of Set 12 | jizan
# Processing Record 41 of Set 12 | bambanglipuro
# Processing Record 42 of Set 12 | champerico
# Processing Record 43 of Set 12 | sainte-anne-des-monts
# Processing Record 44 of Set 12 | goiania
# Processing Record 45 of Set 12 | kaplice
# Processing Record 46 of Set 12 | picsi
# Processing Record 47 of Set 12 | lorengau
# Processing Record 48 of Set 12 | haines junction
# Processing Record 49 of Set 12 | manbij
# Processing Record 50 of Set 12 | zheleznodorozhnyy
# Processing Record 1 of Set 13 | cherskiy
# Processing Record 2 of Set 13 | sao joao batista
# Processing Record 3 of Set 13 | gillette
# Processing Record 4 of Set 13 | saint anthony
# Processing Record 5 of Set 13 | izvestkovyy
# Processing Record 6 of Set 13 | upernavik
# Processing Record 7 of Set 13 | puro
# Processing Record 8 of Set 13 | potchefstroom
# Processing Record 9 of Set 13 | mulki
# Processing Record 10 of Set 13 | alofi
# Processing Record 11 of Set 13 | brae
# Processing Record 12 of Set 13 | portland
# Processing Record 13 of Set 13 | jalu
# Processing Record 14 of Set 13 | salamiyah
# Processing Record 15 of Set 13 | altay
# Processing Record 16 of Set 13 | ranong
# Processing Record 17 of Set 13 | san cristobal
# Processing Record 18 of Set 13 | aitape
# Processing Record 19 of Set 13 | taksimo
# Processing Record 20 of Set 13 | belaya gora
# Processing Record 21 of Set 13 | wageningen
# Processing Record 22 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 13 | katobu
# Processing Record 24 of Set 13 | najran
# Processing Record 25 of Set 13 | saryozek
# Processing Record 26 of Set 13 | houma
# Processing Record 27 of Set 13 | dalianwan
# Processing Record 28 of Set 13 | mbandaka
# Processing Record 29 of Set 13 | felipe carrillo puerto
# Processing Record 30 of Set 13 | banes
# Processing Record 31 of Set 13 | conceicao da barra
# Processing Record 32 of Set 13 | tadine
# Processing Record 33 of Set 13 | kyren
# Processing Record 34 of Set 13 | blagoyevo
# Processing Record 35 of Set 13 | hirara
# Processing Record 36 of Set 13 | tyrma
# Processing Record 37 of Set 13 | ligayan
# Processing Record 38 of Set 13 | alta floresta
# Processing Record 39 of Set 13 | san borja
# Processing Record 40 of Set 13 | vuktyl
# Processing Record 41 of Set 13 | sambava
# Processing Record 42 of Set 13 | rabo de peixe
# Processing Record 43 of Set 13 | mnogovershinnyy
# Processing Record 44 of Set 13 | lamont
# Processing Record 45 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 46 of Set 13 | muros
# Processing Record 47 of Set 13 | manavalakurichi
# Processing Record 48 of Set 13 | tambacounda
# Processing Record 49 of Set 13 | konstantinovskoye
# Processing Record 50 of Set 13 | vada
# Processing Record 1 of Set 14 | dunda
# Processing Record 2 of Set 14 | puerto escondido
# Processing Record 3 of Set 14 | ishigaki
# Processing Record 4 of Set 14 | pangnirtung
# Processing Record 5 of Set 14 | auki
# Processing Record 6 of Set 14 | alice springs
# Processing Record 7 of Set 14 | rongcheng
# Processing Record 8 of Set 14 | swakopmund
# Processing Record 9 of Set 14 | teguldet
# Processing Record 10 of Set 14 | hualmay
# Processing Record 11 of Set 14 | manokwari
# Processing Record 12 of Set 14 | angra
# City not found. Skipping...
# Processing Record 13 of Set 14 | kavaratti
# Processing Record 14 of Set 14 | kyra
# Processing Record 15 of Set 14 | grand-santi
# Processing Record 16 of Set 14 | yagodnoye
# Processing Record 17 of Set 14 | ust-omchug
# Processing Record 18 of Set 14 | ballina
# Processing Record 19 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 14 | tsabong
# Processing Record 21 of Set 14 | nanortalik
# Processing Record 22 of Set 14 | costinesti
# Processing Record 23 of Set 14 | fasa
# Processing Record 24 of Set 14 | rio grande
# Processing Record 25 of Set 14 | moyale
# Processing Record 26 of Set 14 | balas
# Processing Record 27 of Set 14 | talaya
# Processing Record 28 of Set 14 | baft
# Processing Record 29 of Set 14 | oga
# Processing Record 30 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 31 of Set 14 | nyurba
# Processing Record 32 of Set 14 | mount isa
# Processing Record 33 of Set 14 | healdsburg
# Processing Record 34 of Set 14 | zatoka
# Processing Record 35 of Set 14 | monrovia
# Processing Record 36 of Set 14 | berdigestyakh
# Processing Record 37 of Set 14 | alexandria
# Processing Record 38 of Set 14 | zabol
# Processing Record 39 of Set 14 | marshfield
# Processing Record 40 of Set 14 | kangaatsiaq
# Processing Record 41 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 14 | cascais
# Processing Record 43 of Set 14 | mandalgovi
# Processing Record 44 of Set 14 | upata
# Processing Record 45 of Set 14 | kathu
# Processing Record 46 of Set 14 | grande-riviere
# City not found. Skipping...
# Processing Record 47 of Set 14 | sesheke
# Processing Record 48 of Set 14 | casablanca
# Processing Record 49 of Set 14 | elko
# Processing Record 50 of Set 14 | ahome
# Processing Record 1 of Set 15 | ojinaga
# Processing Record 2 of Set 15 | comodoro rivadavia
# Processing Record 3 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 15 | lima
# Processing Record 5 of Set 15 | sao raimundo das mangabeiras
# Processing Record 6 of Set 15 | uaua
# Processing Record 7 of Set 15 | nanakuli
# Processing Record 8 of Set 15 | monster
# Processing Record 9 of Set 15 | yangambi
# Processing Record 10 of Set 15 | armidale
# Processing Record 11 of Set 15 | okha
# Processing Record 12 of Set 15 | simplicio mendes
# Processing Record 13 of Set 15 | nalut
# Processing Record 14 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 15 | darfield
# Processing Record 16 of Set 15 | bud
# Processing Record 17 of Set 15 | hamilton
# Processing Record 18 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 15 | tynda
# Processing Record 20 of Set 15 | port blair
# Processing Record 21 of Set 15 | matamoros
# Processing Record 22 of Set 15 | ocotal
# Processing Record 23 of Set 15 | kashi
# Processing Record 24 of Set 15 | high level
# Processing Record 25 of Set 15 | itaituba
# Processing Record 26 of Set 15 | ust-maya
# Processing Record 27 of Set 15 | avera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0      New Norfolk      AU  2020-11-09 04:10:46 -42.78  147.06     78.01
# 1           Dikson      RU  2020-11-09 04:10:46  73.51   80.55     -1.41
# 2           Palmer      US  2020-11-09 04:10:46  42.16  -72.33     48.00
# 3          Rikitea      PF  2020-11-09 04:10:46 -23.12 -134.97     73.09
# 4  Arraial Do Cabo      BR  2020-11-09 04:10:46 -22.97  -42.03     73.90
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        28          37        3.00    scattered clouds
# 1        91          95       14.65     overcast clouds
# 2       100           1        0.60           clear sky
# 3        78          89       15.66          light rain
# 4        93          70        8.12       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
